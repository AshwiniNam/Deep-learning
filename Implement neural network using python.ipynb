# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
# %matplotlib inline
import matplotlib as plt

# %%
df = pd.read_csv('insurance_data.csv')
df
# Out:
#     age  affordibility  bought_insurance
# 0    22              1                 0
# 1    25              0                 0
# 2    47              1                 1
# 3    52              0                 0
# 4    46              1                 1
# 5    56              1                 1
# 6    55              0                 0
# 7    60              0                 1
# 8    62              1                 1
# 9    61              1                 1
# 10   18              1                 0
# 11   28              1                 0
# 12   27              0                 0
# 13   29              0                 0
# 14   49              1                 1
# 15   55              1                 1
# 16   25              0                 1
# 17   58              1                 1
# 18   19              0                 0
# 19   18              1                 0
# 20   21              1                 0
# 21   26              0                 0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df[['age','affordibility']],df.bought_insurance,test_size=0.2)

# %%
X_test
# Out:
#     age  affordibility
# 4    46              1
# 1    25              0
# 8    62              1
# 7    60              0
# 10   18              1
# 12   27              0

# %%
X_train_scaled = X_train.copy()

# %%
X_train_scaled['age']=X_train_scaled['age']/100

# %%
X_test_scaled = X_test.copy()
X_test_scaled['age']=X_test_scaled['age']/100

# %%
X_test_scaled
# Out:
#      age  affordibility
# 4   0.46              1
# 1   0.25              0
# 8   0.62              1
# 7   0.60              0
# 10  0.18              1
# 12  0.27              0

# %%
model = keras.Sequential([
    keras.layers.Dense(1,input_shape=(2,),activation='sigmoid',kernel_initializer='ones',bias_initializer='zeros') #initialize weights 1 bias 0
])

model.compile( optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy']
)

model.fit(X_train_scaled,y_train,epochs=5000)
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 1s 545ms/step - loss: 0.7322 - accuracy: 0.5000
# Epoch 2/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7318 - accuracy: 0.5000
# Epoch 3/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7313 - accuracy: 0.5000
# Epoch 4/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7309 - accuracy: 0.5000
# Epoch 5/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7305 - accuracy: 0.5000
# Epoch 6/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7301 - accuracy: 0.5000
# Epoch 7/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7296 - accuracy: 0.5000
# Epoch 8/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7292 - accuracy: 0.5000
# Epoch 9/5000
# 1/1 [==============================] - 0s 0s/step - loss: 0.7288 - accuracy: 0.5000
# Epoch 10/5000
# ...

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 1/1 [==============================] - 0s 164ms/step - loss: 0.3566 - accuracy: 0.8333
# [0.35655859112739563, 0.8333333134651184]

# %%
coef,intercept = model.get_weights()
coef,intercept
# Out:
# (array([[4.70179  ],
#         [1.5771617]], dtype=float32),
#  array([-3.0031846], dtype=float32))

# %% [markdown]
# #### Using pure python code

# %%
import math
def sigmoid(x):
    return 1/(1+math.exp(-x))
sigmoid(18)
# Out:
# 0.9999999847700205

# %%
def pred(age,affordability):
    weighted_sum = coef[0]*age+coef[1]*affordability+intercept
    return sigmoid(weighted_sum)

# %%
pred(0.47,1)
# Out:
# 0.6865025004412353

# %%
pred(0.18,1)
# Out:
# 0.3590014635680726

# %% [markdown]
# #### Gradient Descent

# %%
def npsigmoid(X):
    return 1/(1+np.exp(-X))

# %%
npsigmoid(np.array([1,22,34]))
# Out:
# array([0.73105858, 1.        , 1.        ])

# %%
def log_loss(y_true, y_predicted):
    epsilon = 1e-15
    y_predicted_new = [max(i,epsilon) for i in y_predicted]
    y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
    y_predicted_new = np.array(y_predicted_new)
    return -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))

# %%
class myNN:
    def __init(self):
        self.w1 = 1
        self.w2 = 1
        self.bias = 0
        
    def fit(self,X,y,epochs,loss_threshold):
        self.w1,self.w2,self.bias = self.gradient_descent(X['age'],X['affordibility'],y,epochs,loss_threshold)
        
    def predict(self,X_test):
        weighted_sum = X_test['age']*self.w1+X_test['affordibility']*self.w2+self.bias
        return npsigmoid(weighted_sum)
    
    def gradient_descent(self,age,affordibility,y_true,epochs,loss_threshold):
        #returns w1,w2,bias
        w1=w2=1
        bias=0
        rate = 0.5
        n=len(age)
        for i in range(epochs):
            weighted_sum = w1*age+w2*affordibility+bias
            y_predicted = npsigmoid(weighted_sum)
            loss = log_loss(y_true,y_predicted)

            w1d = (1/n)*np.dot(np.transpose(age),(y_predicted-y_true))
            w2d = (1/n)*np.dot(np.transpose(affordibility),(y_predicted-y_true))
            bd = np.mean(y_predicted-y_true)

            w1=w1-rate*w1d
            w2=w2-rate*w2d
            bias=bias-rate*bd

            print(f'Epoch:{i},w1:{w1},w2:{w2},bias:{bias},loss:{loss}')
            if loss<=loss_threshold:
                break
        return w1,w2,bias

# %%
coef,intercept
# Out:
# (array([[4.70179  ],
#         [1.5771617]], dtype=float32),
#  array([-3.0031846], dtype=float32))

# %%
customModel = myNN()
customModel.fit(X_train_scaled,y_train,epochs=5000,loss_threshold=0.4631)
# Out:
# Epoch:0,w1:0.9704904371109808,w2:0.9347420113748803,bias:-0.12224548637710671,loss:0.7322160709795764
# Epoch:1,w1:0.9474727883061175,w2:0.8815520182392611,bias:-0.22801928453908094,loss:0.695014029059035
# Epoch:2,w1:0.9304325087693832,w2:0.8396132323439907,bias:-0.3187084336831002,loss:0.6682235540805537
# Epoch:3,w1:0.9186903925754302,w2:0.8077207588321682,bias:-0.3960770860101789,loss:0.6493807327968986
# Epoch:4,w1:0.9115034397170346,w2:0.784493286313094,bias:-0.462018619755204,loss:0.6363053350952595
# Epoch:5,w1:0.9081423788322087,w2:0.7685411151800726,bias:-0.5183697763253773,loss:0.6272517344895175
# Epoch:6,w1:0.9079394105092464,w2:0.7585731836043046,bias:-0.5667993241046799,loss:0.6209201175316577
# Epoch:7,w1:0.9103106569803,w2:0.7534506092889698,bias:-0.6087583111144257,loss:0.6163919335614193
# Epoch:8,w1:0.9147613729110983,w2:0.7522029993383486,bias:-0.6454714250490846,loss:0.6130418140379308
# ...

# %%
coef,intercept
# Out:
# (array([[4.70179  ],
#         [1.5771617]], dtype=float32),
#  array([-3.0031846], dtype=float32))

# %%
customModel.predict(X_test_scaled)
# Out:
# 4     0.681036
# 1     0.113754
# 8     0.827748
# 7     0.430842
# 10    0.340494
# 12    0.124384
# dtype: float64

# %%
model.predict(X_test_scaled)
# Out:
# 1/1 [==============================] - 0s 146ms/step
# array([[0.6762958 ],
#        [0.13850807],
#        [0.81594115],
#        [0.45459777],
#        [0.35900146],
#        [0.15011477]], dtype=float32)
